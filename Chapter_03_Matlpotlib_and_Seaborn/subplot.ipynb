# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y1 = [1,4,9,16,25]
y2 = [2,4,6,8,10]
y3 = [3,6,9,12,15]
y4 = [1,8,27,64,125]

plt.subplot(2,2,1)
plt.plot(x,y1)
plt.xlabel("x")
plt.ylabel("f(x)")

plt.subplot(2,2,2)
plt.plot(x,y2)
plt.xlabel("x")
plt.ylabel("f(x)")

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.xlabel("x")
plt.ylabel("f(x)")

plt.subplot(2,2,4)
plt.plot(x,y4)
plt.xlabel("x")
plt.ylabel("f(x)")

plt.ti
plt.tight_layout()
